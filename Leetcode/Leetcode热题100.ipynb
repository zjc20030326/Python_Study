# %%
a=10
print(a)
# Out:
# 10

# %%
b=20
a*b
# Out:
# 200

# %%
x = [1, 2, 3]
x[1:3]
x[0:0]
# Out:
# []

# %%
from collections import Counter

c = Counter(["a", "b", "a"])
c.values()
# Out:
# dict_values([2, 1])
