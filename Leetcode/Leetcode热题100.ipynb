# %%
a=10
print(a)
# Out:
# 10

# %%
b=20
a*b
# Out:
# 200

# %%
x = [1, 2, 3]
x[1:3]
x[0:0]
# Out:
# []

# %%
from collections import Counter

c = Counter(["a", "b", "a"])
c.values()
# Out:
# dict_values([2, 1])

# %%
Counter("AB") - Counter("AABC")
# Out:
# Counter()

# %%
a = [2, 3, 1]
a.sort()
print(a)
# Out:
# [1, 2, 3]

# %%
groups = {0: [[2, 15], [0, 3]], -1: [(1, 9)], 1: [(1, 20)], 2: [(2, 7)]}
groups.get(3, -2)
# Out:
# -2
